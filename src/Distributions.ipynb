# %% [markdown]
# <a href="https://colab.research.google.com/github/wbfrench1/Intro_to_Stats_w_Python/blob/main/src/Distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=3bb0c20438e743079cb7ac80a1241553733510dfb1aaf90f3039f93852d3f4de
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
import pandas as pd
import numpy as np
import zipfile
import os
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# # Get Data

# %%
# get data
# !wget https://github.com/wbfrench1/Intro_to_Stats_w_Python/raw/main/data/archive.zip

path_to_zip_file = os.getcwd() + '/archive.zip'
# unzip data
with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
    zip_ref.extractall(os.getcwd())

# %%
# link to original dataset: https://www.kaggle.com/datasets/rhuebner/human-resources-data-set?resource=download&select=HRDataset_v14.csv
# linke to the codebook: https://rpubs.com/rhuebner/hrd_cb_v14

df = pd.read_csv('HRDataset_v14.csv')

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
print('df.shape:', df.shape)
df.describe()
# Out:
# df.shape: (311, 36)
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# ...

# %% [markdown]
# ## Investigate Gender

# %%
np.median(df['GenderID'])
# Out:
# 0.0

# %%
fig, ax = plt.subplots()
values, bins, bars = ax.hist(df['GenderID'], bins=6);
labels =  [int(value) if value !=0 else '' for value in values ]
ax.bar_label(bars, labels =labels)
# Out:
# [Text(0, 0, '176'),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '135')]

# %%
# Out:
# [176, '', '', '', '', '', '', '', '', 135]

# %%
stats.mode(df['GenderID'])
# Out:
# ModeResult(mode=0, count=176)
